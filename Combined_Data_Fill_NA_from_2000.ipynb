# %%
import pandas as pd
import numpy as np
import seaborn as sns 
import matplotlib.pyplot as plt
import pylab

# %%
pylab.rcParams['figure.figsize'] = 10, 8
# %matplotlib inline

# %%
df = pd.read_csv('./data/data_cleaned/combined_data_state_level_from_2000.csv')

# %%
df.isnull().sum()
# Out:
# state                                   0
# year                                    0
# enroll                                  0
# total_revenue                           0
# federal_revenue                         0
# state_revenue                           0
# local_revenue                           0
# total_expenditure                       0
# instruction_expenditure                 0
# support_services_expenditure            0
# other_expenditure                       0
# capital_outlay_expenditure              0
# avg_attendence_elem_secd_schools       51
# teachers_elem_secd_schools            306
# high_school_completers_18_to_24       510
# bachelor_completers_over_25           510
# pupil_teacher_ratio                   255
# pub_high_school_graduates             153
# expenditure_per_pupil                  51
# edu_expenditure_percent_gov_income     18
# population                              0
# gdp_per_capita                          0
# ...

# %% [markdown]
# # Deal with NaNs using pchip

# %%
for s in df.state.unique():
    df[df.state == s] = df[df.state == s].interpolate(method = 'pchip',limit_direction = 'both')

# %%
df.head()
# Out:
#         state  year     enroll  total_revenue  federal_revenue  state_revenue  \
# 0     Alabama  2000   730184.0        4885917           425978        3003814
# 1      Alaska  2000   132822.0        1313510           199520         774194
# 2     Arizona  2000   814807.0        5479168           534619        2481089
# 3    Arkansas  2000   450751.0        2844855           254735        2126099
# 4  California  2000  5941946.0       46628207          4024940       26877920
#
#    local_revenue  total_expenditure  instruction_expenditure  \
# 0        1456125            5003267                  2551713
# 1         339796            1386904                   717725
# 2        2463460            5397194                  2488932
# 3         464021            2683400                  1531232
# 4       15725347           45829753                 23514388
#
#    support_services_expenditure        ...          pupil_teacher_ratio  \
# ...

# %%
df.isnull().sum()
# Out:
# state                                  0
# year                                   0
# enroll                                 0
# total_revenue                          0
# federal_revenue                        0
# state_revenue                          0
# local_revenue                          0
# total_expenditure                      0
# instruction_expenditure                0
# support_services_expenditure           0
# other_expenditure                      0
# capital_outlay_expenditure             0
# avg_attendence_elem_secd_schools       0
# teachers_elem_secd_schools             0
# high_school_completers_18_to_24        0
# bachelor_completers_over_25            0
# pupil_teacher_ratio                    0
# pub_high_school_graduates              0
# expenditure_per_pupil                  0
# edu_expenditure_percent_gov_income    16
# population                             0
# gdp_per_capita                         0
# state_tax_collection                  80
# ...

# %% [markdown]
# # Drop State_Tax_Collection

# %%
df =df.drop('state_tax_collection', axis = 1)

# %%
df.head()
# Out:
#         state  year     enroll  total_revenue  federal_revenue  state_revenue  \
# 0     Alabama  2000   730184.0        4885917           425978        3003814
# 1      Alaska  2000   132822.0        1313510           199520         774194
# 2     Arizona  2000   814807.0        5479168           534619        2481089
# 3    Arkansas  2000   450751.0        2844855           254735        2126099
# 4  California  2000  5941946.0       46628207          4024940       26877920
#
#    local_revenue  total_expenditure  instruction_expenditure  \
# 0        1456125            5003267                  2551713
# 1         339796            1386904                   717725
# 2        2463460            5397194                  2488932
# 3         464021            2683400                  1531232
# 4       15725347           45829753                 23514388
#
#    support_services_expenditure        ...          \
# 0                       1319053        ...
# ...

# %%
df.isnull().sum()
# Out:
# state                                  0
# year                                   0
# enroll                                 0
# total_revenue                          0
# federal_revenue                        0
# state_revenue                          0
# local_revenue                          0
# total_expenditure                      0
# instruction_expenditure                0
# support_services_expenditure           0
# other_expenditure                      0
# capital_outlay_expenditure             0
# avg_attendence_elem_secd_schools       0
# teachers_elem_secd_schools             0
# high_school_completers_18_to_24        0
# bachelor_completers_over_25            0
# pupil_teacher_ratio                    0
# pub_high_school_graduates              0
# expenditure_per_pupil                  0
# edu_expenditure_percent_gov_income    16
# population                             0
# gdp_per_capita                         0
# income_per_capita                      0
# ...

# %%
df[df.edu_expenditure_percent_gov_income.isnull()]
# Out:
#                     state  year   enroll  total_revenue  federal_revenue  \
# 8    District of Columbia  2000  70762.0         881423           184825
# 59   District of Columbia  2001  68925.0        1042261           114876
# 110  District of Columbia  2002  68449.0        1138126           141514
# 161  District of Columbia  2003  67522.0        1114061           152599
# 212  District of Columbia  2004  65099.0        1081501           167020
# 263  District of Columbia  2005  62306.0        1109605           167922
# 314  District of Columbia  2006  59616.0        1092863           127371
# 365  District of Columbia  2007  56943.0        1148358           134700
# 416  District of Columbia  2008  58191.0        1224312            85568
# 467  District of Columbia  2009  44331.0         801008            75856
# 518  District of Columbia  2010  43866.0        1195934            80585
# 569  District of Columbia  2011  44199.0        1283071           155505
# ...

# %%
#df.to_csv('./data/data_cleaned/combined_data_state_level_na_filled_from_2000.csv', index = False)
